# %%
import pandas as pd

y = {'Unusual Fatigue': [-13.3, -36.7, -33.3, -26.7, -20.0, -20.0, -23.3, -23.3],
     'Headache': [None, None, None, -40, -40, -40, -40, -30],
     'Depression': [None, None, None, -10.0, -6.7, -6.7, -6.7, -6.7],
     'Sleeping Problems': [-10, -20, -40, -60, None, None, None, None]}
x = [1, 2, 3, 4, 5, 6, 7, 8]
graph = pd.DataFrame(y,x)
graph.plot(kind ='line', color={'Unusual Fatigue':"#aaaaff", 'Headache':"#ff4400", 'Depression': "#000000", 'Sleeping Problems':"#3333cc"}, 
           title='Hospitalization due to Prolonged NV in month 4', xlabel='month', ylabel='percent')

# %%
import pandas as pd

y = {'LTNV (w13-16)': [20.9, 55.4, 56.2, 47.5, 32.1, 24.9, 27.6, 26.8],
     'LTNV (w17-20)': [21.7, 54.7, 55.1, 46.6, 36.2, 28.3, 29.6, 28.3],
     'LTNV (w21-24)': [23.0, 54.4, 53.7, 43.7, 35.2, 31.5, 33.3, 30.0],
     'LTNV (w25-28)': [24.5, 55.4, 54.3, 40.2, 32.1, 30.4, 37.0, 33.2],
     'LTNV (w29+)': [24.3, 55.6, 54.2, 40.3, 30.6, 27.8, 34.7, 37.5],
     'No LTNV (w13-16)': [23.5, 54.1, 52.5, 25.6, 15.8, 13.3, 15.9, 15.0],
     'No LTNV (w17-20)': [23.3, 54.2, 52.7, 26.5, 16.2, 13.6, 16.3, 15.4],
     'No LTNV (w21-24)': [23.3, 54.2, 52.8, 27.1, 16.7, 13.9, 16.6, 15.7],
     'No LTNV (w25-28)': [23.2, 54.2, 52.8, 27.3, 17.0, 14.1, 16.6, 15.7],
     'No LTNV (w29+)': [23.2, 54.2, 52.8, 27.4, 17.0, 14.2, 16.7, 15.7]}
x = [0, 5, 9, 13, 17, 21, 25, 29]

graph = pd.DataFrame(y,x)
graph.plot(kind ='line', grid=True, title="Unusual fatigue/drowsiness", ylabel= "percent", xlabel = "week")

# %%
y = {'LTNV (w13-16)': [3.7, 9.7, 13.9, 16.3],
     'LTNV (w17-20)': [3.8, 9.8, 14.3, 17.4],
     'LTNV (w21-24)': [3.8, 9.8, 14.3, 17.4],
     'LTNV (w25-28)': [4.9, 10.3, 14.1, 18.5],
     'LTNV (w29+)': [4.9, 10.4, 13.9, 18.8],
     'No LTNV (w13-16)': [2.6, 5.9, 8.0, 9.5],
     'No LTNV (w17-20)': [2.6, 6.1, 8.2, 9.8],
     'No LTNV (w21-24)': [2.6, 6.1, 8.2, 9.8],
     'No LTNV (w25-28)': [2.6, 6.2, 8.4, 10.0],
     'No LTNV (w29+)': [2.6, 6.2, 8.5, 10.0]}
x = [0, 5, 9, 13]

graph = pd.DataFrame(y,x)
graph.plot(kind ='line', grid=True, title="Sleeping problems", ylabel= "percent", xlabel = "week")

# %%
y = {'LTNV (w13-16)': [14.9,	15.8, 14.7, 14.9, 11.1],
     'LTNV (w17-20)': [14.9, 16.8, 15.8, 15.3, 11.7],
     'LTNV (w21-24)': [15.2, 17.0, 17.4, 17.0, 13.3],
     'LTNV (w25-28)': [15.2, 16.8, 17.9, 18.5, 14.1],
     'LTNV (w29+)': [13.9, 16.0, 16.0, 17.4, 17.4],
     'No LTNV (w13-16)': [8.1, 8.4, 7.9, 8.4, 6.2],
     'No LTNV (w17-20)': [8.4, 8.6, 8.1, 8.7, 6.3],
     'No LTNV (w21-24)': [8.5, 8.8, 8.3, 8.8, 6.4],
     'No LTNV (w25-28)': [8.6, 8.9, 8.3, 8.8, 6.5],
     'No LTNV (w29+)': [8.6, 9.0, 8.4, 8.9, 6.5]}
x = [13, 17, 21, 25, 29]

graph = pd.DataFrame(y,x)
graph.plot(kind ='line', grid=True, title="Headache/migraine", ylabel= "percent", xlabel = "week")

# %%
y = {'LTNV (w13-16)': [3.8, 3.5, 3.9, 4.1, 3.4],
     'LTNV (w17-20)': [3.8, 3.8, 4.2, 4.5, 3.4],
     'LTNV (w21-24)': [4.8, 4.8, 5.2, 5.6, 4.4],
     'LTNV (w25-28)': [4.3, 4.3, 5.4, 6.5, 4.3],
     'LTNV (w29+)': [4.2, 4.2, 5.6, 6.2, 5.6],
     'No LTNV (w13-16)': [1.3, 1.4, 1.6, 2.0, 1.5],
     'No LTNV (w17-20)': [1.4, 1.4, 1.7, 2.1, 1.6],
     'No LTNV (w21-24)': [1.5, 1.5, 1.7, 2.1, 1.6],
     'No LTNV (w25-28)': [1.5, 1.5, 1.8, 2.1, 1.6],
     'No LTNV (w29+)': [1.5, 1.5, 1.8, 2.2, 1.6]
     
    }
x = [13, 17, 21, 25, 29]

graph = pd.DataFrame(y,x)
graph.plot(kind ='line', grid=True, title="Depression", ylabel= "percent", xlabel = "week")

# %%
import pandas as pd

y = {'LTNV (w13-16)': [75.6, 19.9, 2.8, 1.0, 0.8],
     'LTNV (w17-20)': [74.7, 20.4, 3.0, 0.9, 0.9],
     'LTNV (w21-24)': [71.7, 22.3, 4.3, 1.1, 1.1],
     'LTNV (w25-28)': [71.7, 22.3, 4.3, 1.1, 1.1],
     'LTNV (w29+)': [70.1, 22.2, 4.9, 1.4, 0.7],
     'No LTNV (w13-16)': [73.5, 13.8, 1.7, 0.5, 10.5],
     'No LTNV (w17-20)': [73.6, 14.0, 1.7, 0.5, 10.1],
     'No LTNV (w21-24)': [73.7, 14.2, 1.7, 0.5, 9.8],
     'No LTNV (w25-28)': [73.7, 14.2, 1.7, 0.5, 9.8],
     'No LTNV (w29+)': [73.7, 14.3, 1.7, 0.5, 9.8]}
x = [0,1,2,3,4]

graph = pd.DataFrame(y,x)
graph.plot(kind ='line', grid=True, title="Feeling fearful", ylabel= "percent", xlabel = "0=Not bothered, 1=A little bothered, 2=Quite bothered, 3=Very bothered, 4=missing")

# %%
import pandas as pd

y = {'LTNV (w13-16)': [81.5, 14.5, 2.2, 0.9, 1.0],
     'LTNV (w17-20)': [81.3, 14.2, 2.5, 0.9, 1.1],
     'LTNV (w21-24)': [78.9, 15.6, 3.0, 1.1, 1.5],
     'LTNV (w25-28)': [16.3, 78.3, 3.3, 1.1, 1.1],
     'LTNV (w29+)': [17.4, 76.4, 1.4, 3.5, 1.4],
     'No LTNV (w13-16)': [77.0, 10.6, 1.3, 0.4, 10.7],
     'No LTNV (w17-20)': [77.2, 10.8, 1.3, 0.4, 10.3],
     'No LTNV (w21-24)': [77.3, 10.9, 1.3, 0.4, 10.0],
     'No LTNV (w25-28)': [77.4, 10.9, 1.3, 0.4, 10.0],
     'No LTNV (w29+)': [77.4, 10.9, 1.3, 0.4, 9.9]}
x = [0,1,2,3,4]

graph = pd.DataFrame(y,x)
graph.plot(kind ='line', grid=True, title="Feeling hopeless about the future", ylabel= "percent", xlabel = "0=Not bothered, 1=A little bothered, 2=Quite bothered, 3=Very bothered, 4=missing")

# %%
import pandas as pd

y = {'LTNV (w13-16)': [48.1, 37.3, 6.7, 1.7, 6.2],
     'LTNV (w17-20)': [46.8, 37.2, 7.5, 1.9, 6.6],
     'LTNV (w21-24)': [44.4, 38.1, 8.9, 2.2, 6.3],
     'LTNV (w25-28)': [42.9, 38.6, 9.8, 2.7, 5.4],
     'LTNV (w29+)': [41.7, 38.9, 9.7, 3.5, 6.2],
     'No LTNV (w13-16)': [52.0, 28.6, 3.8, 0.7, 14.9],
     'No LTNV (w17-20)': [51.9, 28.9, 3.8, 0.8, 14.5],
     'No LTNV (w21-24)': [51.9, 29.1, 3.9, 0.8, 14.3],
     'No LTNV (w25-28)': [51.8, 29.2, 3.9, 0.8, 14.2],
     'No LTNV (w29+)': [51.8, 29.2, 4.0, 0.8, 14.2]}
x = [0,1,2,3,4]

graph = pd.DataFrame(y,x)
graph.plot(kind ='line', grid=True, title="Feeling everything is an effort", ylabel= "percent", xlabel = "0=Not bothered, 1=A little bothered, 2=Quite bothered, 3=Very bothered, 4=missing")

# %%
import pandas as pd

y = {'LTNV (w13-16)': [65.9, 24.0, 3.2, 0.6, 6.3],
     'LTNV (w17-20)': [65.7, 23.6, 3.6, 0.6, 6.6],
     'LTNV (w21-24)': [64.8, 24.1, 4.1, 0.7, 6.3],
     'LTNV (w25-28)': [64.1, 25.0, 4.9, 1.1, 5.4],
     'LTNV (w29+)': [62.5, 25.0, 5.6, 0.7, 6.2],
     'No LTNV (w13-16)': [64.3, 18.5, 2.0, 0.3, 14.9],
     'No LTNV (w17-20)': [64.3, 18.7, 2.0, 0.3, 14.6],
     'No LTNV (w21-24)': [64.4, 18.8, 2.1, 0.3, 14.4],
     'No LTNV (w25-28)': [64.4, 18.9, 2.1, 0.4, 14.3],
     'No LTNV (w29+)': [64.4, 18.9, 2.1, 0.4, 14.3]}
x = [0,1,2,3,4]

graph = pd.DataFrame(y,x)
graph.plot(kind ='line', grid=True, title="Feeling tense or keyed up", ylabel= "percent", xlabel = "0=Not bothered, 1=A little bothered, 2=Quite bothered, 3=Very bothered, 4=missing")

# %%
import pandas as pd

y = {'LTNV (w13-16)': [85.0, 7.2, 1.1, 0.4, 6.3],
     'LTNV (w17-20)': [84.0, 7.9, 1.1, 0.6, 6.4],
     'LTNV (w21-24)': [83.0, 8.5, 1.5, 0.7, 6.3],
     'LTNV (w25-28)': [83.2, 9.2, 1.6, 0.5, 5.4],
     'LTNV (w29+)': [80.6, 10.4, 2.1, 0.7, 6.2],
     'No LTNV (w13-16)': [79.2, 14.9, 5.2, 0.6, 0.2],
     'No LTNV (w17-20)': [79.5, 5.2, 0.6, 0.2, 14.5],
     'No LTNV (w21-24)': [79.6, 5.3, 0.6, 0.2, 14.3],
     'No LTNV (w25-28)': [79.6, 5.3, 0.6, 0.2, 14.3],
     'No LTNV (w29+)': [79.7, 5.3, 0.6, 0.2, 14.2]}
x = [0,1,2,3,4]

graph = pd.DataFrame(y,x)
graph.plot(kind ='line', grid=True, title="Suddenly scared for no reason", ylabel= "percent", xlabel = "0=Not bothered, 1=A little bothered, 2=Quite bothered, 3=Very bothered, 4=missing")

# %%
import pandas as pd

y = {'LTNV (w13-16)': [31.7, 52.2, 9.6, 0.6, 0.1, 5.6],
     'LTNV (w17-20)': [31.9, 51.3, 10.0, 0.8, 0.2, 5.8],
     'LTNV (w21-24)': [31.9, 51.1, 10.4, 1.1, 0.0, 5.6],
     'LTNV (w25-28)': [32.6, 49.5, 12.0, 1.1, 0.0, 4.9],
     'LTNV (w29+)': [31.9, 49.3, 12.5, 0.7, 0.0, 5.6],
     'No LTNV (w13-16)': [27.4, 49.3, 8.4, 0.4, 0.1, 14.4],
     'No LTNV (w17-20)': [27.6, 49.4, 8.4, 0.5, 0.1, 14.0],
     'No LTNV (w21-24)': [27.7, 49.5, 8.5, 0.5, 0.1, 13.8],
     'No LTNV (w25-28)': [27.7, 49.5, 8.4, 0.5, 0.1, 13.8],
     'No LTNV (w29+)': [27.7, 49.5, 8.5, 0.5, 0.1, 13.7]}
x = [0,1,2,3,4,5]

graph = pd.DataFrame(y,x)
graph.plot(kind ='line', grid=True, title="Feel glad about something", ylabel= "percent", xlabel = "0=Very often, 1=Often, 2=Sometimes, 3=Seldom, 4=Seldom/never, 5=missing")

# %%
import pandas as pd

y = {'LTNV (w13-16)': [25.5, 49.1, 17.3, 2.1, 0.3, 5.7],
     'LTNV (w17-20)': [26.2, 47.7, 17.2, 2.3, 0.4, 5.8],
     'LTNV (w21-24)': [26.7, 47.0, 17.4, 2.6, 0.7, 5.6],
     'LTNV (w25-28)': [28.3, 44.6, 19.0, 2.7, 0.5, 4.9],
     'LTNV (w29+)': [27.8, 45.1, 18.8, 2.1, 0.0, 5.6],
     'No LTNV (w13-16)': [22.8, 45.9, 15.1, 1.6, 0.2, 14.5],
     'No LTNV (w17-20)': [22.8, 46.0, 15.2, 1.6, 0.2, 14.1],
     'No LTNV (w21-24)': [22.9, 46.1, 15.2, 1.6, 0.2, 13.9],
     'No LTNV (w25-28)': [22.9, 46.2, 15.2, 1.7, 0.2, 13.8],
     'No LTNV (w29+)': [22.9, 46.2, 15.2, 1.7, 0.2, 13.8]}
x = [0,1,2,3,4,5]

graph = pd.DataFrame(y,x)
graph.plot(kind ='line', grid=True, title="Feel happy", ylabel= "percent", xlabel = "0=Very often, 1=Often, 2=Sometimes, 3=Seldom, 4=Seldom/never, 5=missing")
